# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
books = pd.read_csv("Books.csv", dtype={"Column_Name": str}, low_memory=False)
ratings = pd.read_csv("Ratings.csv")
books_data = books.merge(ratings, on="ISBN")

# %%
# Preprocessing
df = books_data.copy()
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)
df.drop(columns=["ISBN", "Year-Of-Publication", "Image-URL-S", "Image-URL-M"], axis=1, inplace=True)
df.drop(index=df[df["Book-Rating"] == 0].index, inplace=True)
df["Book-Title"] = df["Book-Title"].apply(lambda x: re.sub(r"[^\w\s]+", " ", x).strip())

# %%
# Function to get popular books
def popular_books(df, n=100):
    rating_count = df.groupby("Book-Title").count()["Book-Rating"].reset_index()
    rating_count.rename(columns={"Book-Rating": "NumberOfVotes"}, inplace=True)

    rating_average = df.groupby("Book-Title")["Book-Rating"].mean().reset_index()
    rating_average.rename(columns={"Book-Rating": "AverageRatings"}, inplace=True)

    popularBooks = rating_count.merge(rating_average, on="Book-Title")

    def weighted_rate(x):
        v = x["NumberOfVotes"]
        R = x["AverageRatings"]
        return ((v * R) + (m * C)) / (v + m)

    C = popularBooks["AverageRatings"].mean()
    m = popularBooks["NumberOfVotes"].quantile(0.90)

    popularBooks = popularBooks[popularBooks["NumberOfVotes"] >= 250]
    popularBooks["Popularity"] = popularBooks.apply(weighted_rate, axis=1)
    popularBooks = popularBooks.sort_values(by="Popularity", ascending=False)
    return popularBooks[["Book-Title", "NumberOfVotes", "AverageRatings", "Popularity"]].reset_index(drop=True).head(n)

# %%
# Display top popular books
top_ten = popular_books(df, 5)
print("📘 MOST POPULAR 5 BOOKS")
print(top_ten)
# Out:
# 📘 MOST POPULAR 5 BOOKS
#                                           Book-Title  NumberOfVotes  \
# 0   Harry Potter and the Prisoner of Azkaban  Book 3            277
# 1                              To Kill a Mockingbird            267
# 2  Harry Potter and the Sorcerer s Stone  Harry P...            315
# 3    Harry Potter and the Chamber of Secrets  Book 2            326
# 4  Tuesdays with Morrie  An Old Man  a Young Man ...            250
#
#    AverageRatings  Popularity
# 0        9.043321    9.016359
# 1        8.977528    8.950784
# 2        8.936508    8.914416
# 3        8.840491    8.820584
# 4        8.588000    8.567111

# %%
# Select a book for recommendations
book_names = df["Book-Title"].value_counts().index[:200]
print("\nChoose the book you're reading for advice:")
for i, name in enumerate(book_names):
    print(f"{i + 1}: {name}")
# Out:
# Choose the book you're reading for advice:
# 1: The Lovely Bones  A Novel
# 2: Wild Animus
# 3: The Da Vinci Code
# 4: The Secret Life of Bees
# 5: The Nanny Diaries  A Novel
# 6: The Red Tent  Bestselling Backlist
# 7: Bridget Jones s Diary
# 8: A Painted House
# 9: Life of Pi
# 10: Harry Potter and the Chamber of Secrets  Book 2
# 11: Divine Secrets of the Ya Ya Sisterhood  A Novel
# 12: Harry Potter and the Sorcerer s Stone  Harry Potter  Paperback
# 13: Angels  amp  Demons
# 14: The Summons
# 15: Where the Heart Is  Oprah s Book Club  Paperback
# 16: The Notebook
# 17: Girl with a Pearl Earring
# 18: Harry Potter and the Prisoner of Azkaban  Book 3
# 19: Snow Falling on Cedars
# 20: The Pilot s Wife   A Novel
# 21: To Kill a Mockingbird
# 22: The Catcher in the Rye
# 23: Timeline
# 24: The Testament
# 25: The Girls  Guide to Hunting and Fishing
# 26: Summer Sisters
# 27: Tuesdays with Morrie  An Old Man  a Young Man  and Life s Greatest Lesson
# 28: Harry Potter and the Goblet of Fire  Book 4
# 29: Good in Bed
# 30: The Five People You Meet in Heaven
# 31: House of Sand and Fog
# 32: 1st to Die  A Novel
# 33: Interview with the Vampire
# 34: Suzanne s Diary for Nicholas
# 35: The Firm
# 36: The Poisonwood Bible  A Novel
# 37: Me Talk Pretty One Day
# 38: She s Come Undone  Oprah s Book Club
# 39: A Time to Kill
# 40: Dreamcatcher
# 41: The Brethren
# 42: Jurassic Park
# 43: Harry Potter and the Order of the Phoenix  Book 5
# 44: The Joy Luck Club
# 45: She s Come Undone  Oprah s Book Club  Paperback
# 46: The Chamber
# 47: Fahrenheit 451
# 48: The Street Lawyer
# 49: The Partner
# 50: The Fellowship of the Ring  The Lord of the Rings  Part 1
# 51: The Pelican Brief
# 52: The Reader
# 53: The Runaway Jury
# 54: The Rainmaker
# 55: The Bean Trees
# 56: The Beach House
# 57: The Client
# 58: Empire Falls
# 59: Little Altars Everywhere  A Novel
# 60: The King of Torts
# 61: The No  1 Ladies  Detective Agency  Today Show Book Club  8
# 62: The Horse Whisperer
# 63: The Bridges of Madison County
# 64: Red Dragon
# 65: A Prayer for Owen Meany
# 66: Hannibal
# 67: Message in a Bottle
# 68: White Oleander   A Novel
# 69: Harry Potter and the Sorcerer s Stone  Book 1
# 70: Nickel and Dimed  On  Not  Getting By in America
# 71: Skipping Christmas
# 72: White Oleander   A Novel  Oprah s Book Club
# 73: The Divine Secrets of the Ya Ya Sisterhood  A Novel
# 74: Left Behind  A Novel of the Earth s Last Days  Left Behind No  1
# 75: A Walk to Remember
# 76: The Bonesetter s Daughter
# 77: Confessions of a Shopaholic  Summer Display Opportunity
# 78: SHIPPING NEWS
# 79: The Hobbit   The Enchanting Prelude to The Lord of the Rings
# 80: The Golden Compass  His Dark Materials  Book 1
# 81: While I Was Gone
# 82: Bel Canto  A Novel
# 83: Stupid White Men  and Other Sorry Excuses for the State of the Nation
# 84: A Bend in the Road
# 85: Wicked  The Life and Times of the Wicked Witch of the West
# 86: Fast Food Nation  The Dark Side of the All American Meal
# 87: Midwives  A Novel
# 88: Ender s Game  Ender Wiggins Saga  Paperback
# 89: American Gods
# 90: Into Thin Air   A Personal Account of the Mt  Everest Disaster
# 91: 2nd Chance
# 92: How to Be Good
# 93: The Cider House Rules
# 94: Chocolat
# 95: Violets Are Blue
# 96: 1984
# 97: Neverwhere
# 98: The Color Purple
# 99: A Heartbreaking Work of Staggering Genius
# 100: When the Wind Blows
# 101: The Vampire Lestat  Vampire Chronicles  Book II
# 102: Icy Sparks
# 103: The Last Time They Met   A Novel
# 104: Outlander
# 105: We Were the Mulvaneys
# 106: Sphere
# 107: Prodigal Summer  A Novel
# 108: Digital Fortress   A Thriller
# 109: The Perfect Storm   A True Story of Men Against the Sea
# 110: STONES FROM THE RIVER
# 111: Angela s Ashes  MMP    A Memoir
# 112: A Child Called  It  One Child s Courage to Survive
# 113: ANGELA S ASHES
# 114: The Hitchhiker s Guide to the Galaxy
# 115: The Two Towers  The Lord of the Rings  Part 2
# 116: Into the Wild
# 117: Seven Up  A Stephanie Plum Novel
# 118: Misery
# 119: Cold Mountain   A Novel
# 120: Watership Down
# 121: One for the Money  Stephanie Plum Novels  Paperback
# 122: The Alienist
# 123: Seabiscuit  An American Legend
# 124: Lucky   A Memoir
# 125: Mystic River
# 126: One Door Away from Heaven
# 127: Black Notice
# 128: About a Boy
# 129: The Rescue
# 130: The Last Precinct
# 131: Balzac and the Little Chinese Seamstress   A Novel
# 132: The Hours  A Novel
# 133: Airframe
# 134: Fried Green Tomatoes at the Whistle Stop Cafe
# 135: Fall On Your Knees  Oprah  45
# 136: High Fidelity
# 137: The Alchemist  A Fable About Following Your Dream
# 138: The Handmaid s Tale
# 139: Hard Eight   A Stephanie Plum Novel  A Stephanie Plum Novel
# 140: The God of Small Things
# 141: Lord of the Flies
# 142: Girl  Interrupted
# 143: The Bad Beginning  A Series of Unfortunate Events  Book 1
# 144: The Hundred Secret Senses
# 145: Silence of the Lambs
# 146: Brave New World
# 147: Tara Road
# 148: Animal Farm
# 149: Dolores Claiborne
# 150: Along Came a Spider  Alex Cross Novels
# 151: Insomnia
# 152: The Great Gatsby
# 153: The Kitchen God s Wife
# 154: A Map of the World
# 155: Q Is for Quarry
# 156: Cradle and All
# 157: Bridget Jones  The Edge of Reason
# 158: The Book of Ruth  Oprah s Book Club  Paperback
# 159: The Green Mile
# 160: Point of Origin
# 161: The Tao of Pooh
# 162: Full House  Janet Evanovich s Full Series
# 163: The Poisonwood Bible
# 164: Two for the Dough
# 165: The Witching Hour  Lives of the Mayfair Witches
# 166: The Color of Water  A Black Man s Tribute to His White Mother
# 167: Pop Goes the Weasel
# 168: The Smoke Jumper
# 169: O  Is for Outlaw
# 170: Midnight in the Garden of Good and Evil  A Savannah Story
# 171: Artemis Fowl  Artemis Fowl  Book 1
# 172: The Subtle Knife  His Dark Materials  Book 2
# 173: Isle of Dogs
# 174: I Know This Much Is True
# 175: Unnatural Exposure
# 176: A Walk in the Woods  Rediscovering America on the Appalachian Trail  Official Guides to the Appalachian Trail
# 177: Dance upon the Air  Three Sisters Island Trilogy
# 178: Four Blind Mice
# 179: Naked
# 180: The Return of the King  The Lord of the Rings  Part 3
# 181: Tell No One
# 182: Four To Score  A Stephanie Plum Novel
# 183: Pigs in Heaven
# 184: The Blind Assassin
# 185: Black House
# 186: The Giver  21st Century Reference
# 187: A Is for Alibi  Kinsey Millhone Mysteries  Paperback
# 188: It
# 189: Pet Sematary
# 190: Sophie s World  A Novel About the History of Philosophy
# 191: Back Roads
# 192: The Lost World
# 193: Daddy s Little Girl
# 194: Deception Point
# 195: Don t Sweat the Small Stuff and It s All Small Stuff   Simple Ways to Keep the Little Things from Taking Over Your Life  Don t Sweat the Small Stuff Series
# 196: The Queen of the Damned  Vampire Chronicles  Paperback
# 197: Congo
# 198: Disclosure
# 199: Cause of Death
# 200: Night

# %%
def content_based(bookTitle):
    bookTitle = str(bookTitle)
    img_list_content = []

    if bookTitle in df["Book-Title"].values:
        rating_count = pd.DataFrame(df["Book-Title"].value_counts())
        rare_books = rating_count[rating_count["Book-Title"] <= 200].index
        common_books = df[~df["Book-Title"].isin(rare_books)]

        if bookTitle in rare_books:
            print("No Recommendations for this Book ☹️")
        else:
            common_books = common_books.drop_duplicates(subset=["Book-Title"])
            common_books.reset_index(inplace=True)
            common_books["index"] = [i for i in range(common_books.shape[0])]
            targets = ["Book-Title", "Book-Author", "Publisher"]
            common_books["all_features"] = [" ".join(common_books[targets].iloc[i,].values) for i in range(common_books[targets].shape[0])]
            vectorizer = CountVectorizer()
            common_booksVector = vectorizer.fit_transform(common_books["all_features"])
            similarity = cosine_similarity(common_booksVector)
            index = common_books[common_books["Book-Title"] == bookTitle]["index"].values[0]
            similar_books = list(enumerate(similarity[index]))
            similar_booksSorted = sorted(similar_books, key=lambda x: x[1], reverse=True)[1:6]
            books = [common_books[common_books["index"] == similar_booksSorted[i][0]]["Book-Title"].item() for i in range(len(similar_booksSorted))]

            print("\n📕 OTHER USERS' SELECTIONS")
            for book in books:
                img_url = common_books.loc[common_books["Book-Title"] == book, "Image-URL-L"][:1].values[0]
                img_list_content.append(img_url)
                print(book, img_url)

content_based(books)
